# %% [markdown]
# *Might be interesting:* Short [article](http://scienceblogs.com/cognitivedaily/2007/03/29/most-researchers-dont-understa/) on error bars and significance

# %% [markdown]
# # Instructions
# 1. To run notebook, go to the `Cell` menu above and click `Run All`.
# 2. To hide all the code, just click the `Results Only` button above.
# 3. If something goes really wrong, then go to the `Kernel` menu above and click `Restart` and repeat Step 1.
#
# You can interact with the plot below to select which combination of groups and dates you want to show.
# You can CTRL+Click to select multiple items in the menus below.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib
import matplotlib.gridspec as gridspec
import seaborn.apionly as sns
import numpy as np
import pandas as pd
import IPython.html.widgets as widgets
import os

from ggplot import *

from IPython.html.widgets import \
    interact,\
    interactive,\
    fixed

from IPython.display import \
    display,\
    clear_output

from pandas.tools.plotting import \
    scatter_matrix

from pandas import \
    DataFrame as df

from view import \
    plot_plates,\
    matrix_tree
    
from toolz import \
    pipe,\
    thread_first
    
from utils import \
    normalize_columns,\
    filter_and_drop,\
    filter_rows,\
    snd,\
    add_col,\
    get_files,\
    gen_filenames,\
    maybe_get_model,\
    persist_widget_value,\
    concatenate,\
    are_all_in

# %%
matplotlib.style.use('ggplot')

# %%
path = '/notebooks/Seahorse/'
files = filter(lambda x: not x.startswith('.'), os.listdir(path))

# %%
data_files = filter(lambda f: 'data' in f,files)
norm_files = filter(lambda f: 'Norm' in f,files)

# %%
def rename_measurement_col(name):
    if 'Measure' in name:
        return name.split()[0]
    else: 
        return name
    
# String -> DataFrame
def get_data(filename,date):
    return thread_first(
        filename,
        pd.read_csv,
        lambda d: d.rename(columns=rename_measurement_col),
        lambda d: add_col(d,'Date',date))

# String -> DataFrame
def get_norm(filename,date):
    return thread_first(
        filename,
        lambda x: pd.read_csv(x,header=-1,names=['Group','Factor']),
        lambda d: d.rename(columns=rename_measurement_col),
        lambda d: add_col(d,'Date',date))

# %%
raw_data = pd.concat(
    [get_data(os.path.join(path,filename),filename.split()[0])
        for filename in data_files]).dropna(how='all',axis=1)

# %%
norm_data = pd.concat(
    [get_norm(os.path.join(path,filename),filename.split()[0])
        for filename in norm_files]).rename(columns = {'Back. Corr.': "Group"})
norm_data['Group'] = norm_data['Group'].map(lambda x: x.lstrip(' ').rstrip(' '))

# %%
raw_and_norm_data = pd.merge(raw_data,norm_data, on = ['Date','Group'],how='left')

# %%
background_data = raw_and_norm_data[raw_and_norm_data['Group'] == 'Back. Corr.']

# %%
background_means = \
    background_data\
    .groupby(['Date','Measurement'])\
    .mean()\
    .reset_index()\
    .rename(
        columns={"OCR":"Background OCR",
                 "ECAR": "Background ECAR"})\
    .drop('Factor',axis=1)

# %%
background_means.dropna(how = 'all',axis=1)
# Out:
#     Date  Measurement  Background ECAR  Background OCR
# 0   7-17            1          -8.8700        -37.8850
# 1   7-17            2          -1.3475        -15.9525
# 2   7-17            3           1.1450        -16.1975
# 3   7-17            4           1.5250         -9.7475
# 4   7-17            5           1.7975         -4.9900
# 5   7-17            6           2.6125        -10.5300
# 6   7-17            7           2.3875        -10.2650
# 7   7-17            8           2.6500        -10.9000
# 8   7-17            9           2.3375         -1.9450
# 9   7-17           10           2.4875          2.2375
# 10  7-17           11           2.2275         -4.5250
# 11  7-17           12           2.8350         -3.7075
# 12  7-17           13           3.2575         -3.9600
# 13  7-17           14           2.6600         -7.5525
# 14  7-19            1          -6.5975        -11.5400
# 15  7-19            2          -0.7650         -9.7675
# 16  7-19            3           2.3275         -1.5000
# 17  7-19            4           2.4150         -0.2850
# 18  7-19            5           3.5975          0.8950
# 19  7-19            6           1.9475          5.0200
# 20  7-19            7           3.4100          7.4300
# 21  7-19            8           3.8100          1.6125
# 22  7-19            9           3.7175          4.5800
# 23  7-19           10           3.2050          6.8725
# 24  7-19           11           2.9375          5.1525
# 25  7-19           12           2.4925          4.1825
# 26  7-19           13           2.7000          8.1150
# 27  7-19           14           5.1800          1.0675
# 28  7-20            1          -7.1600        -15.5725
# 29  7-20            2          -0.4950        -11.0625
# 30  7-20            3           1.7025         -7.7825
# 31  7-20            4           3.7425         -1.4800
# 32  7-20            5           4.1625         -1.1175
# 33  7-20            6           2.9150          6.7900
# 34  7-20            7           3.1300          4.0175
# 35  7-20            8           3.3500          0.1825
# 36  7-20            9           3.0925          6.0575
# 37  7-20           10           3.7775          3.0575
# 38  7-20           11           3.3775          3.1825
# 39  7-20           12           3.7600          0.6850
# 40  7-20           13           3.4225          0.6150
# 41  7-20           14           3.4500         -1.9225

# %%
data = pd.merge(raw_and_norm_data,
                background_means,
                on=['Date','Measurement'])

# %%
# DataFrame -> Boolean -> Boolean -> DataFrame
def subtract_background_and_normalize(data,subtract_background = True, normalize = True):
    """ Given a dataframe, return a copy with the background subtracted 
        and data rescaled by the given factor. """
    new_data = data.copy()
    if subtract_background:
        new_data['OCR'] = new_data['OCR'] - new_data['Background OCR']
        new_data['ECAR'] = new_data['ECAR'] - new_data['Background ECAR']
    if normalize:
        new_data['OCR'] = new_data['OCR'] * new_data['Factor']
        new_data['ECAR'] = new_data['ECAR'] * new_data['Factor']
    return new_data

# %%
def plot_results(data, groups, dates,subtract_background, normalize, show_errorbars, show_error_fill, show_median, error_measure, parameter):
    
    groups = list(groups)
    dates = list(dates)
    
    new_data = subtract_background_and_normalize(data,subtract_background, normalize)
    filtered_groups = new_data[new_data['Group'].isin(groups)]
    filtered_dates = filtered_groups[filtered_groups['Date'].isin(dates)]
    
    groupbys = filtered_dates.groupby(['Measurement','Group'])
    means = groupbys.mean()[[parameter]].unstack()[parameter]
    medians = groupbys.median()[[parameter]].unstack()[parameter]
    stds =  groupbys.std()[[parameter]].unstack()[parameter]
    sems =  groupbys.sem()[[parameter]].unstack()[parameter]
    
    # fill, errorbars, error measure
    
    if error_measure == 'SEM':
        errs = sems
    else: 
        errs = stds
    
    if show_median:
        medians.plot(kind='line', linewidth = 2)
#         for group in filtered_dates['Group'].unique().tolist():
#             plt.plot(medians.index, medians[group],'--')
    
    else:
        if show_errorbars:
            means.plot(kind='line', yerr = errs, linewidth = 2, capsize=3, capthick = 4, fmt = '-o')
        else:
            means.plot(kind='line', linewidth = 2)
    
    if show_error_fill:
        for group in filtered_dates['Group'].unique().tolist():
            plt.fill_between(means.index, means[group] - errs[group], means[group] + errs[group], alpha=0.3)
     
    fig = plt.gcf()
    fig.set_size_inches(17,8)
    plt.ylabel(parameter)
    plt.title("{}{}{}{}".format(
        parameter,
        ', normalized' if normalize else '',
        ', minus background' if subtract_background else '',
        ' (errorbars = {})'.format(error_measure) if show_errorbars or show_error_fill else ''))

# %%
group_options = data['Group'].unique().tolist()
date_options = sorted(data['Date'].unique().tolist())

interact(
    plot_results,
    data = fixed(data),
    groups = widgets.SelectMultiple(
        options = group_options,
        value = group_options),
    dates = widgets.SelectMultiple(
        options = date_options,
        value = date_options),
    subtract_background = True, 
    normalize = True, 
    show_errorbars = True, 
    show_error_fill = True,
    show_median = False,
    error_measure = widgets.ToggleButtons(
        options = ['SEM','STD'],
        value = 'SEM'),
    parameter = widgets.ToggleButtons(
        options = ['OCR','ECAR'],
        value = 'OCR'));

# %% [markdown]
# # Show individual points

# %%
def plot_points(data, groups, dates,subtract_background, normalize, parameter):
    np.random.seed(10030423)
    groups = list(groups)
    dates = list(dates)
    
    new_data = subtract_background_and_normalize(data,subtract_background, normalize)
    filtered_groups = new_data[new_data['Group'].isin(groups)]
    filtered_dates = filtered_groups[filtered_groups['Date'].isin(dates)]
    
    if not groups |are_all_in| filtered_dates['Group'].unique().tolist():
        missing_groups = list(set(groups).difference(set(filtered_dates['Group'].unique().tolist())))
        print "It looks like there might not be data for these groups for the day(s) you've chosen: {} .".format(' '.join(missing_groups))
        return
    jittered_data = filtered_dates[filtered_dates['Group'].isin(groups)].copy()
    jitter_strength = 0.4
    jittered_data['Measurement'] = jittered_data['Measurement'].map(lambda x: x + np.random.random() * jitter_strength)
    
    display(ggplot(aes(x = 'Measurement',y = parameter, color = 'Group'), data = jittered_data.reset_index(drop=True)) + geom_point());

# %%
interact(
    plot_points,
    data = fixed(data),
    groups = widgets.SelectMultiple(
        options = group_options,
        value = group_options),
    dates = widgets.SelectMultiple(
        options = date_options,
        value = date_options),
    subtract_background = True, 
    normalize = True, 
    parameter = widgets.ToggleButtons(
        options = ['OCR','ECAR'],
        value = 'OCR'));
# Out:
# <ggplot: (8775483367109)>

# %%
# pip uninstall ggplot
# pip install git+git://github.com/yhat/ggplot.git

# %%
data.to_csv('/notebooks/seahorse-data.csv',index=False)

# %%
# d[d['Date'] == '7-17'].groupby(['Measurement','Group']).mean()

# %%
data['Date'].unique()
# Out:
# array(['7-19', '7-17', '7-20'], dtype=object)

# %%
mysems = data.groupby(['Date','Measurement','Group']).sem().reset_index()
mymeans = data.groupby(['Date','Measurement','Group']).mean().reset_index()

# %%
mymeans.to_csv('/notebooks/seahorse-means.csv',index=False)
mysems.to_csv('/notebooks/seahorse-sems.csv',index=False)

# %%
from IPython.display import FileLink, FileLinks
FileLinks('/notebooks/')
# Out:
# /notebooks/
#   random number generation.ipynb
#   07-16-15.tar
#   seahorse-sems.csv
#   seahorse-means.csv
#   EconDataFromDee.csv
#   seahorse-data.csv
# /notebooks/.ipynb_checkpoints/
#   draft-parsing multiplate datasets-checkpoint.ipynb
#   random number generation-checkpoint.ipynb
#   06-19-2015-checkpoint.ipynb
# /notebooks/Seahorse/
#   7-19 OCAR-ECAR data.csv
#   7-19 Normalization.csv
#   7-17 OCAR-ECAR data.csv
#   7-20 OCAR-ECAR data.csv
#   7-20 Normalization.csv
#   7-17 Normalization.csv
# /notebooks/assay-explorer/
#   Economics.ipynb
#   DATAVIS - 6.19.2015 - ssC.ipynb
#   DATAVIS - 7.15.2015 - ssC-PNA-Refactor.ipynb
#   Seahorse.ipynb
#   DATAVIS - 7.15.2015 - APB-PNA.ipynb
#   DATAVIS - 6.24.2015 - ssC-PNA-Copy1.ipynb
#   DATAVIS - 6.19.2015 - APB.ipynb
#   Untitled.ipynb
#   DATAVIS - 7.15.2015 - ssC-PNA.ipynb
#   DATAVIS - 6.24.2015 - ssC-PNA.ipynb
#   .gitignore
#   Economics-Copy1.ipynb
#   DATAVIS - 7.15.2015 - ssC-PNA-CellPhase.ipynb
#   DATAVIS - 7.15.2015 - APB-PNA-CellPhase.ipynb
#   DATAVIS - 6.24.2015 - ssC-LNA.ipynb
# /notebooks/assay-explorer/.git/
#   ORIG_HEAD
#   HEAD
#   index
#   COMMIT_EDITMSG
#   config
#   description
#   packed-refs
# /notebooks/assay-explorer/.git/hooks/
#   pre-rebase.sample
#   applypatch-msg.sample
#   commit-msg.sample
#   pre-push.sample
#   pre-applypatch.sample
#   update.sample
#   prepare-commit-msg.sample
#   pre-commit.sample
#   post-update.sample
# /notebooks/assay-explorer/.git/info/
#   exclude
# /notebooks/assay-explorer/.git/logs/
#   HEAD
# /notebooks/assay-explorer/.git/logs/refs/heads/
#   master
# /notebooks/assay-explorer/.git/logs/refs/remotes/origin/
#   HEAD
#   master
# /notebooks/assay-explorer/.git/objects/00/
#   1fa0ecf9cf365b249643bc63712c0e398df3f4
# /notebooks/assay-explorer/.git/objects/01/
#   da3b8401cc5e7b4047d551e25e1d28e490d946
#   1f018a1086d72e2af9e424da14538d8d5b98dd
# /notebooks/assay-explorer/.git/objects/04/
#   b8ddd8c3222dfb646d66b104d2ae00a98ce592
#   413f67f27b0bfc8c9b2918834ea46adc487a66
#   ab2494918d939f42f65fe270b741b5c7a1fff7
#   4d7f392680c6a7a328841d6d4681af6f1772e0
#   bc845fe4e18594721fa7bb98c40f58914536c7
#   78a0c4a298f68f63bf63dcd678f4d8f7eabb2f
# /notebooks/assay-explorer/.git/objects/05/
#   306baf8335efa07ede5178363bb711678d7721
#   c39c5fe1b744d823194c87560264808b9241f3
# /notebooks/assay-explorer/.git/objects/06/
#   d966653a142f85ac3762789e299b77e95e3a11
#   ae732ef870b011a8264625f9f96b0a114366f6
# /notebooks/assay-explorer/.git/objects/07/
#   86a6dbf546cd4a86c2dd27ca14c7fd55843e72
#   0070787a939157fb86c833fe75f6ba040cfe6b
# /notebooks/assay-explorer/.git/objects/08/
#   5fac91ac5801593d0f04bccc2afae90e4a061f
#   0b17af077dff9134f9057202a8e86fc8870e3e
#   1da4d43ad621eb6783dfdf8befdd859e2f6af2
# /notebooks/assay-explorer/.git/objects/fc/
#   7f5985d8ebe941d1e2cedf38a20b3a9779f35b
# /notebooks/assay-explorer/.git/objects/ff/
#   a61622cf5306d7da581f1ea88ccba1ad334892
# /notebooks/assay-explorer/.git/objects/pack/
#   pack-03ffbaac1f337d4f210dd4f46ca21ea7c5711e22.pack
#   pack-03ffbaac1f337d4f210dd4f46ca21ea7c5711e22.idx
# /notebooks/assay-explorer/.git/refs/heads/
#   master
# /notebooks/assay-explorer/.git/refs/remotes/origin/
#   HEAD
#   master
# /notebooks/assay-explorer/.ipynb_checkpoints/
#   Seahorse-checkpoint.ipynb
#   DATAVIS - 7.15.2015 - ssC-PNA-Refactor-checkpoint.ipynb
#   DATAVIS - 6.24.2015 - ssC-LNA-checkpoint.ipynb
#   DATAVIS - 7.15.2015 - ssC-PNA-CellPhase-checkpoint.ipynb
#   DATAVIS - 7.15.2015 - ssC-PNA-checkpoint.ipynb
#   DATAVIS - 6.24.2015 - ssC-PNA-Copy1-checkpoint.ipynb
#   DATAVIS - 6.19.2015 - APB-checkpoint.ipynb
#   DATAVIS - 6.24.2015 - ssC-PNA-checkpoint.ipynb
#   DATAVIS - 7.15.2015 - APB-PNA-checkpoint.ipynb
#   Economics-checkpoint.ipynb
#   DATAVIS - 6.19.2015 - ssC-checkpoint.ipynb
#   DATAVIS - 7.15.2015 - APB-PNA-CellPhase-checkpoint.ipynb
#   Untitled-checkpoint.ipynb
#   Economics-Copy1-checkpoint.ipynb
# /notebooks/assay-explorer/nb/
#   aggregate.ipynb
#   Labeling cell phase.ipynb
#   playground.ipynb
#   Traits.ipynb
#   07-15-2015 ssC & APB PNA.ipynb
#   06-19-2015 ssC & APB.ipynb
#   07-15-2015 ssC & APB PNA-Refactor.ipynb
#   06-24-2015 ssC LNA & PNA.ipynb
#   06-22-2015 APB Drug Screen.ipynb
# /notebooks/assay-explorer/nb/.ipynb_checkpoints/
#   06-24-2015 ssC LNA & PNA-checkpoint.ipynb
#   07-15-2015 ssC & APB PNA-checkpoint.ipynb
#   playground-checkpoint.ipynb
#   Labeling cell phase-checkpoint.ipynb
#   aggregate-checkpoint.ipynb
#   Traits-checkpoint.ipynb
#   07-15-2015 ssC & APB PNA-Refactor-checkpoint.ipynb
#   06-19-2015 ssC & APB-checkpoint.ipynb
#   06-22-2015 APB Drug Screen-checkpoint.ipynb
# /notebooks/assay-explorer/reorg/
#   raw.pyc
#   aggregate.ipynb
#   utils.pyc
#   view.pyc
#   Widgets.ipynb
#   Seahorse.ipynb
#   utils.py
#   raw.py
#   DATAVIS - 7.15.2015 - ssC-PNA.ipynb
#   Seahorse-2-Copy1.ipynb
#   Seahorse-2.ipynb
#   07-15-2015 ssC & APB PNA - reorg.ipynb
#   view.py
#   ui_model.json
# /notebooks/assay-explorer/reorg/.ipynb_checkpoints/
#   Seahorse-checkpoint.ipynb
#   DATAVIS - 7.15.2015 - ssC-PNA-checkpoint.ipynb
#   Seahorse-2-Copy1-checkpoint.ipynb
#   aggregate-checkpoint.ipynb
#   Widgets-checkpoint.ipynb
#   07-15-2015 ssC & APB PNA - reorg-checkpoint.ipynb
#   Seahorse-2-checkpoint.ipynb
# /notebooks/assay-explorer/src/
#   aggregate.py
#   moldev_utils.py
#   utils.pyc
#   analyze.py
#   merge_macro_creator.py
#   example_analysis.py
#   cellslib.py
#   utils.py
#   display_utils.py
#   cell.py
# /notebooks/assay-explorer/src/.ipynb_checkpoints/
#   06-19-2015-Copy1-checkpoint.ipynb
#   06-19-2015-checkpoint.ipynb
# /notebooks/assay-explorer/test/
#   compare_summary.ipynb
# /notebooks/assay-explorer/test/.ipynb_checkpoints/
#   Untitled1-checkpoint.ipynb
#   Main-checkpoint.ipynb
#   Frequencies above one-checkpoint.ipynb
#   Deploy-Copy1-checkpoint.ipynb
#   Deploy-checkpoint.ipynb
#   Untitled2-checkpoint.ipynb
#   Untitled3-checkpoint.ipynb
#   compare_summary-checkpoint.ipynb
#   Untitled-checkpoint.ipynb
# /notebooks/assay-explorer/test/summary/
#   check_summary.ipynb
#   excel_summary.csv
#   moldev_summary.csv
# /notebooks/assay-explorer/test/summary/.ipynb_checkpoints/
#   check_summary-checkpoint.ipynb
# /notebooks/moldev-data/analyzed/06-19-2015/
#   ssC.csv
#   APB-conditions.csv
#   ssC-wells.csv
#   APB.csv
#   APB-wells.csv
#   ssC-conditions.csv
# /notebooks/moldev-data/analyzed/06-24-2015/
#   ssC PNA-wells.csv
#   ssC LNA-conditions.csv
#   ssC PNA-conditions.csv
#   ssC LNA.csv
#   ssC LNA-wells.csv
#   ssC PNA.csv
# /notebooks/moldev-data/analyzed/07-15-2015/
#   ssC PNA-wells.csv
#   ssC PNA-Refactor.csv
#   ssC PNA-conditions.csv
#   APB PNA-wells.csv
#   APB PNA-Refactor.csv
#   APB PNA.csv
#   ssC PNA.csv
#   APB PNA-conditions.csv
# /notebooks/moldev-data/original/05-15-2015/
#   Copy of 12.16.14 APB assay - Drug A, HU, TS - 0.08 to 11.1 uM drug A - experiment started on 11.3.14 v2 post macro.xlsm
# /notebooks/moldev-data/original/05-22-2015/
#   ( ID_110 ) APB Drug A,F Screen HS (60X) 05.21.2015 v2.xlsx
# /notebooks/moldev-data/original/06-19-2015/
#   6.19.15 All APB data - Jonah Simon.txt
#   readme.gdoc
#   6.19.15 All ssC data - Jonah Simon.txt
#   6.19.15 All APB and ssC data - Plate ID and conditions - Jonah Simon.jpg
# /notebooks/moldev-data/original/06-22-2015/
#   9.9.14 HU TS experiment - U2OS, 143B - 48 h culture - 96 wells.png
#   [ ID_103 ] 9.9.14 APB Drug Screen HU TS DH (60X) 11.5.2014.txt
#   readme.gdoc
# /notebooks/moldev-data/original/06-24-2015/
#   ssC HS JS 06.24.2015 PNA.txt
#   ssC HS JS 06.24.2015 LNA.txt
#   readme.gdoc
# /notebooks/moldev-data/original/07-15-2015/
#   [ ID_2 ] PNA probe 50-6 nM APB HS JS (60X) 07.15.2015.txt
#   [ ID_1 ] PNA probe 50-6 nM ssC HS JS (60X) 07.13.2015.txt
