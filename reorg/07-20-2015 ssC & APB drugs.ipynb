# %%
from utils import \
    get_layout_info

# %%
layout_path = '/notebooks/moldev-data/original/07-20-2015/plate-layout.csv'
apb_path = '/notebooks/moldev-data/original/07-20-2015/APB HS JS 60X 07.22.2015 ML216 MMC HU TS.txt'
ssc_path = '/notebooks/moldev-data/original/07-20-2015/ssC HS JS 60X 07.20.2015 ML216 MMC HU TS.txt'

# %%
layout_info = get_layout_info(filepath)

# %%
# Out:
#    Cell Type Well Name       Contents Concentration Units (concentration)
# 0       U2OS        A1  Media Control          0.08                     %
# 1       U2OS        B1  Media Control          0.08                     %
# 2       U2OS        C1  Media Control          0.08                     %
# 3       U2OS        D1  Media Control          0.08                     %
# 4       143b        E1  Media Control          0.08                     %
# 5       143b        F1  Media Control          0.08                     %
# 6       143b        G1  Media Control          0.08                     %
# 7       143b        H1  Media Control          0.08                     %
# 8       U2OS        A2   DMSO Control           0.5                     %
# 9       U2OS        B2   DMSO Control           0.5                     %
# 10      U2OS        C2   DMSO Control           0.5                     %
# 11      U2OS        D2   DMSO Control           0.5                     %
# 12      143b        E2   DMSO Control           0.5                     %
# 13      143b        F2   DMSO Control           0.5                     %
# 14      143b        G2   DMSO Control           0.5                     %
# 15      143b        H2   DMSO Control           0.5                     %
# 16      U2OS        A3          ML216           100                    uM
# 17      U2OS        B3          ML216           100                    uM
# 18      U2OS        C3          ML216           100                    uM
# 19      U2OS        D3          ML216           100                    uM
# 20      143b        E3          ML216           100                    uM
# 21      143b        F3          ML216           100                    uM
# 22      143b        G3          ML216           100                    uM
# 23      143b        H3          ML216           100                    uM
# 24      U2OS        A4          ML216            50                    uM
# 25      U2OS        B4          ML216            50                    uM
# 26      U2OS        C4          ML216            50                    uM
# 27      U2OS        D4          ML216            50                    uM
# 28      143b        E4          ML216            50                    uM
# 29      143b        F4          ML216            50                    uM
# ..       ...       ...            ...           ...                   ...
# 66      U2OS        C9            MMC           100                 ng/mL
# 67      U2OS        D9            MMC           100                 ng/mL
# 68      143b        E9            MMC           100                 ng/mL
# 69      143b        F9            MMC           100                 ng/mL
# 70      143b        G9            MMC           100                 ng/mL
# 71      143b        H9            MMC           100                 ng/mL
# 72      U2OS       A10            MMC            50                 ng/mL
# 73      U2OS       B10            MMC            50                 ng/mL
# 74      U2OS       C10            MMC            50                 ng/mL
# 75      U2OS       D10            MMC            50                 ng/mL
# 76      143b       E10            MMC            50                 ng/mL
# 77      143b       F10            MMC            50                 ng/mL
# 78      143b       G10            MMC            50                 ng/mL
# 79      143b       H10            MMC            50                 ng/mL
# 80      U2OS       A11             HU             1                    mM
# 81      U2OS       B11             HU             1                    mM
# 82      U2OS       C11             HU             1                    mM
# 83      U2OS       D11             HU             1                    mM
# 84      143b       E11             HU             1                    mM
# 85      143b       F11             HU             1                    mM
# 86      143b       G11             HU             1                    mM
# 87      143b       H11             HU             1                    mM
# 88      U2OS       A12             TS             5                    uM
# 89      U2OS       B12             TS             5                    uM
# 90      U2OS       C12             TS             5                    uM
# 91      U2OS       D12             TS             5                    uM
# 92      143b       E12             TS             5                    uM
# 93      143b       F12             TS             5                    uM
# 94      143b       G12             TS             5                    uM
# 95      143b       H12             TS             5                    uM
#
# [96 rows x 5 columns]
