# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
from IPython.html.widgets import interact,fixed
import IPython.html.widgets as widgets
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = '/notebooks/EconDataFromDee.csv'
data = pd.read_csv(filename).drop('Unnamed: 0',axis=1)

# %%
subset = data.drop(['Product','Diagnostic (material + labor)'],axis=1)

# %%
def scatter(df,cols):
    scatter_matrix(data[list(cols)], alpha=1, figsize=(10, 5));
    
interact(scatter, 
         df = fixed(subset),
         cols = widgets.SelectMultiple(options= subset.columns.tolist(),height=250));
