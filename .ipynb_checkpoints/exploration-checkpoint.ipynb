# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#http://stanford.edu/~mwaskom/software/seaborn/examples/distplot_options.html

# %% [markdown]
# # TODO:
# - improve initial parsing to ignore some columns

# %%
def rename_func(x):
    "Return part of name prior to parentheses"
    if x.startswith("Cell"):
        return x.split('(')[0].lstrip("Cell: ").rstrip('/').rstrip(' ').lstrip(' ')
    else:
        return x

# %%
columns_to_ignore = ['Well Name.1','Cell ID','Site ID','MEASUREMENT SET ID','Cell: ObjectID (APB Drug A Screen DH (60X) 11.17.2014)']
cells_1 = pd.read_csv('moldev_data.csv',skiprows=4).drop(columns_to_ignore,axis=1)
cells = cells_1.drop([col for col in cells_1.columns if col.endswith('.1')], axis=1).rename(columns=rename_func)
cells.head()
# Out:
#   Well Name  # of FITC spots  Area_FITC  NucArea_Avg  \
# 0       A01               48   0.279027   279.731445
# 1       A01               64   0.294945   271.821320
# 2       A01              107   0.296126   476.046844
# 3       A01               31   0.206960   158.921982
# 4       A01               36   0.205057   152.450043
#
#    NucIntegrated Intensity_Average  Integrated Intensity_FITC  Area_TxRed  \
# 0                         14681150               15103.187500    0.296630
# 1                         21208878               20009.921875    0.342698
# 2                         35930504               18756.439453    0.365602
# 3                          9765546               10159.871094    0.505620
# 4                          9115531               10580.388672    0.381125
#
#    Integrated Intensity_TxRed  # of TxRed spots  Area_APB    ...     \
# 0                10060.700195                10  0.269664    ...
# 1                14770.213867                28  0.233147    ...
# 2                14954.127930                39  0.264748    ...
# 3                22328.845703                13  0.297754    ...
# 4                18221.039063                25  0.179776    ...
#
#    TxRedinAPB_Int_Intensity_Avg  # TxRed in APB  Area_TxRedinAPB_Total  \
# 0                  13321.333008               3               1.134836
# 1                  18355.941406              17               7.078680
# 2                  18644.291016              24              10.606784
# 3                  22653.500000               4               2.224728
# 4                  24807.000000               6               3.325856
#
#    Total_Int_Intensity_FITC  Total_Int_Intensity_TxRed  \
# 0                    724953                     100607
# 1                   1280635                     413566
# 2                   2006939                     583211
# 3                    314956                     290275
# 4                    380894                     455526
#
#    FITCinAPB_Int_Intensity_Total      % APB  % All Coloc Spots  \
# 0                          59308   3.448276           5.172414
# 1                         429914   8.695652          19.565217
# 2                         631949  10.958904          18.493151
# 3                          61833   4.545455           9.090909
# 4                          74126   6.557377           9.836066
#
#    FITC-TxRed_Area_Total  % Coloc Spot Area/PML-TRF2 fused area
# 0              15.752872                               3.851641
# 1              26.011339                               9.460044
# 2              40.966457                              12.150301
# 3              12.213532                               6.347746
# 4              16.078716                               5.171209
#
# [5 rows x 31 columns]

# %%
conds = pd.read_csv('conditions_and_wells.csv',skiprows=[1]).dropna(axis=1,how='all')
conds
# Out:
#   U2OS control U2OS 0.22% DMSO U2OS 11.1 uM drug A U2OS 5.55 uM drug A  \
# 0          A01             A02                 A03                 A04
# 1          B01             B02                 B03                 B04
# 2          C01             C02                 C03                 C04
# 3          D01             D02                 D03                 D04
#
#   U2OS 2.75 uM drug A U2OS 1.38 uM drug A U2OS 0.69 uM drug A  \
# 0                 A05                 A06                 A07
# 1                 B05                 B06                 B07
# 2                 C05                 C06                 C07
# 3                 D05                 D06                 D07
#
#   U2OS 0.34 uM drug A U2OS 0.17 uM drug A U2OS 0.08 uM drug A  \
# 0                 A08                 A09                 A10
# 1                 B08                 B09                 B10
# 2                 C08                 C09                 C10
# 3                 D08                 D09                 D10
#
#           ...         143B 11.1 uM drug A 143B 5.55 uM drug A  \
# 0         ...                         E03                 E04
# 1         ...                         F03                 F04
# 2         ...                         G03                 G04
# 3         ...                         H03                 H04
#
#   143B 2.75 uM drug A 143B 1.38 uM drug A 143B 0.69 uM drug A  \
# 0                 E05                 E06                 E07
# 1                 F05                 F06                 F07
# 2                 G05                 G06                 G07
# 3                 H05                 H06                 H07
#
#   143B 0.34 uM drug A 143B 0.17 uM drug A 143B 0.08 uM drug A 143B 1 mM HU  \
# 0                 E08                 E09                 E10          E11
# 1                 F08                 F09                 F10          F11
# 2                 G08                 G09                 G10          G11
# 3                 H08                 H09                 H10          H11
#
#   143B 5 uM Telomestatin
# 0                    E12
# 1                    F12
# 2                    G12
# 3                    H12
#
# [4 rows x 24 columns]

# %%
def header_to_column(series):
    """Given a Series, return a Dataframe with columns: value, label.
    Created by associating header with each value in Series."""
    return pd.DataFrame(dict(values = series.values,
                             label = series.name))

# %%
def headers_to_column(df):
    """Given Dataframe, return new Dataframe with two columns: value, label. 
    Created by taking each value in table, and pairing it with its column name."""
    return pd.concat([header_to_column(df[col]) for col in df.columns])

# %%
def move_column(df,col,pos):
    """Return new Dataframe where col in moved to pos.
    if pos is 0, then first column becomes col, and all other columns are shifted right."""
    other_cols = [c for c in df.columns if c != col]
    return df[other_cols[0:pos] + [col] + other_cols[pos:]]

# %%
cond_lookup = headers_to_column(conds) \
                .reset_index(drop=True) \
                .rename(columns=dict(values = 'Well Name',
                                     label = 'Condition'))

# %%
cond_lookup.head()
# Out:
#          Condition Well Name
# 0     U2OS control       A01
# 1     U2OS control       B01
# 2     U2OS control       C01
# 3     U2OS control       D01
# 4  U2OS 0.22% DMSO       A02

# %%
data_1 = pd.merge(cells,cond_lookup,on='Well Name')
data = move_column(data_1,'Condition',1)
data.head()
# Out:
#   Well Name     Condition  # of FITC spots  Area_FITC  NucArea_Avg  \
# 0       A01  U2OS control               48   0.279027   279.731445
# 1       A01  U2OS control               64   0.294945   271.821320
# 2       A01  U2OS control              107   0.296126   476.046844
# 3       A01  U2OS control               31   0.206960   158.921982
# 4       A01  U2OS control               36   0.205057   152.450043
#
#    NucIntegrated Intensity_Average  Integrated Intensity_FITC  Area_TxRed  \
# 0                         14681150               15103.187500    0.296630
# 1                         21208878               20009.921875    0.342698
# 2                         35930504               18756.439453    0.365602
# 3                          9765546               10159.871094    0.505620
# 4                          9115531               10580.388672    0.381125
#
#    Integrated Intensity_TxRed  # of TxRed spots        ...         \
# 0                10060.700195                10        ...
# 1                14770.213867                28        ...
# 2                14954.127930                39        ...
# 3                22328.845703                13        ...
# 4                18221.039063                25        ...
#
#    TxRedinAPB_Int_Intensity_Avg  # TxRed in APB  Area_TxRedinAPB_Total  \
# 0                  13321.333008               3               1.134836
# 1                  18355.941406              17               7.078680
# 2                  18644.291016              24              10.606784
# 3                  22653.500000               4               2.224728
# 4                  24807.000000               6               3.325856
#
#    Total_Int_Intensity_FITC  Total_Int_Intensity_TxRed  \
# 0                    724953                     100607
# 1                   1280635                     413566
# 2                   2006939                     583211
# 3                    314956                     290275
# 4                    380894                     455526
#
#    FITCinAPB_Int_Intensity_Total      % APB  % All Coloc Spots  \
# 0                          59308   3.448276           5.172414
# 1                         429914   8.695652          19.565217
# 2                         631949  10.958904          18.493151
# 3                          61833   4.545455           9.090909
# 4                          74126   6.557377           9.836066
#
#    FITC-TxRed_Area_Total  % Coloc Spot Area/PML-TRF2 fused area
# 0              15.752872                               3.851641
# 1              26.011339                               9.460044
# 2              40.966457                              12.150301
# 3              12.213532                               6.347746
# 4              16.078716                               5.171209
#
# [5 rows x 32 columns]

# %%
cs = conds.columns.tolist()
data[data.Condition==cs[0]]['# of FITC spots'].hist(bins=50);
data[data.Condition==cs[17]]['# of FITC spots'].hist(bins=50);

# %%
x = data[['Condition','Area_FITC']].groupby('Condition')

# %%
def remove_nans(x):
    return x[~np.isnan(x)]

# %%
control_dist = ('',x.get_group('U2OS control')['Area_FITC'].values)
dists = [[(name, remove_nans(group['Area_FITC'].values)),control_dist] for name, group in x]

# %%
control_dist
# Out:
# ('', array([ 0.279027,  0.294945,  0.296126, ...,  0.290984,  0.337615,
#          0.295244]))

# %%
len(cs)
# Out:
# 24

# %%
data.to_csv('dump.csv',index=False)

# %%
def get_grid(n):
    "Return number of rows and columns for a given number of plots."
    rows = int(np.floor(np.sqrt(n)))
    cols = int(np.ceil(n/float(rows)))
    return rows,cols

# %%
sns.boxplot(data['Area_FITC'],data['Condition'],color='w')

# %%
def chart_dists2(dists_list):
    """Create a chart for each distribution.
    dists_list: [[(string,[num])]]
    each element of dists_list has a subplot, and each subelement has a labelled histogram."""
    
    sns.set(style="white", palette="muted")
    b,g = sns.color_palette("muted",2)
    n_rows, n_cols = get_grid(len(dists_list))
    f,axes_grid = plt.subplots(n_rows,n_cols,figsize=(15,9))
    axes = np.array(axes_grid).flatten();
    
    for i, dists in enumerate(dists_list):
        for dist,color in zip(dists,sns.color_palette('muted',len(dists))):
#             sns.distplot(dist[1],color=color,ax=axes[i],hist=False)
            sns.distplot(dist[1],color=color,ax=axes[i],kde=False)
            axes[i].set_xlim(0,0.5)
            axes[i].set_ylim(0,150)
            axes[i].text(0,-20,dist[0],color=color)
            
    sns.despine(left=True)
    plt.setp(axes, yticks=[],xticks=[])
    #plt.tight_layout()

# %%
chart_dists2(dists)

# %%
def chart_dists(dists_list):
    """Create a chart for each distribution.
    dists_list: [[(string,[num])]]
    each element of dists_list has a subplot, and each subelement has a labelled histogram."""
    
    sns.set(style="white", palette="muted")
    b,g = sns.color_palette("muted",2)
    n_rows, n_cols = get_grid(len(dists_list))
    f,axes_grid = plt.subplots(n_rows,n_cols,figsize=(15,9))
    axes = np.array(axes_grid).flatten();
    
    for i, dists in enumerate(dists_list):
        for dist,color in zip(dists,sns.color_palette('muted',len(dists))):
            sns.distplot(dist[1],color=color,ax=axes[i],hist=True,norm_hist=False)
            axes[i].set_xlim(0,0.5)
            axes[i].set_ylim(0,20)
            axes[i].text(0,-2,dist[0],color=color)
            
    sns.despine(left=True)
    plt.setp(axes, yticks=[],xticks=[])
    #plt.tight_layout()

# %%
chart_dists(dists)

# %%
#chart_dists([[('',np.random.random(100))],[('',np.random.random(100))],[('',np.random.random(100))]])

# %%
sns.set(style="white", palette="muted")
f, axes = plt.subplots(6, 4, figsize=(3, 3))
sns.despine(left=True)

rs = np.random.RandomState(10)

b, g, r, p = sns.color_palette("muted", 4)

d = rs.normal(size=100)

#sns.distplot(d, kde=False, color=b, ax=axes[0, 0])
#sns.distplot(d, hist=False, rug=True, color=r, ax=axes[0, 1])
sns.distplot(d, hist=False, color=g, kde_kws={"shade": True}, ax=axes[1, 0])
sns.distplot(d, color=g, ax=axes[1, 1])

plt.setp(axes, yticks=[],xticks=[])
plt.tight_layout()
