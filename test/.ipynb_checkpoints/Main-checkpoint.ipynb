# %%
execfile('../src/display_utils.py')
execfile('../src/moldev_utils.py')
# %matplotlib inline

# %%
summary = pd.read_csv('../output/condition_summary.csv')

# %%
colors = {'Blue & Red':'bwr','Blue':'Blues'}

# %% [markdown]
# # Well Plate Results

# %%
plate_data = pd.read_csv('../output/well_summary.csv')
interact(plot_plate, 
         data = fixed(plate_data),
         parameter = widgets.Select(value = 'Cell Count',
                                    options= get_params(plate_data),
                                    height=250),
         function = plate_data['Function'].unique().tolist(),
         color = colors);

# %% [markdown]
# # How do conditions cluster together?

# %%
data = pipe(summary,
            get_means,
            lambda df: df.set_index('Condition'),
            normalize_columns)

# %%
interact(matrix_tree, data = fixed(data), color = colors);

# %% [markdown]
# # Heatmap subsets

# %%
def wrapper(conditions,features,color):
    df = data.loc[list(conditions)][list(features)]
    try: 
        matrix_tree(df,color)
    except:
        print "\n".join(["-"*50, "Please select multiple features and conditions.","-"*50])

subset = interactive(wrapper,
                     conditions = widgets.SelectMultiple(options = data.index.values.tolist(),height = 300),
                     features = widgets.SelectMultiple(options = data.columns.values.tolist(),height = 300),
                     color = colors)
subset

# %% [markdown]
# # How do parameters vary with drug dose?

# %%
dose_data = thread_first(summary,
                        lambda df: df[df['Function'] == 'mean'],
                        add_condition_cols)

dose_error = thread_first(summary,
                        lambda df: df[df['Function'] == 'sem'],
                        add_condition_cols)

# %%
interact(dose_plot,
         scale = widgets.ToggleButtons(options=['linear','log']), 
         df = fixed(dose_data),
         err = fixed(dose_error),
         cols = widgets.SelectMultiple(value = ['Cell Count'],
                              options= [col for col in dose_data.columns.values.tolist() if col not in ['Condition','Function','Base','Dose','Unit','Drug']],
                              height=250));

# %% [markdown]
# #How are different parameters related?

# %%
from pandas.tools.plotting import scatter_matrix

def scatter(df,cols):
    scatter_matrix(data[list(cols)], alpha=1, figsize=(20, 20), diagonal='kde');
    
interact(scatter, 
         df = fixed(filter_rows(dose_data,'Base','143B')),
         cols = widgets.SelectMultiple(value = ['Cell Count'],
                              options= get_params(dose_data),
                              height=250));

# %% [markdown]
# # Parameter vs. Conditions

# %%
raw_cell_data = pd.read_csv('../output/moldev_cleaned.csv')
cell_data = add_condition_cols(raw_cell_data)

# %%
def plot_dist(df,base,parameter, max_shown=3):
    data = df[df['Base'] == base].sort(['Drug','Dose'])
    plt.figure(num=None, figsize=(15, 7), dpi=80, facecolor='w', edgecolor='k')
    sns.boxplot(data[parameter], 
                data['Condition'],
                vert=False,
                order=data.Condition.unique(),
                color=map(colorize,data.Condition.unique()))
    plt.ylabel('Condition',fontsize=20)
    plt.xlabel(parameter,fontsize=20)
    plt.tick_params(labelsize=20)
    mean = data[parameter].mean()
    plt.gca().set_xlim([0 - mean * (max_shown/10),max_shown * mean])

# %%
def get_params(df):
    cols = df.columns.tolist()
    return sorted([col for col in cols if col not in ['Well Name', 'Condition', 'Base', 'Dose', 'Unit', 'Drug','Function']])

# %%
interactive(plot_dist,
            df = fixed(cell_data), 
            base = cell_data.Base.unique().tolist(), 
            parameter = get_params(cell_data))

# %%
cell_data.head()

def plot_kdes(df,conditions,parameters,filter_frequency=1):
    n_rows = int(np.ceil(len(parameters)/3.0))
    plt.figure(figsize=(20,4 * n_rows))
    subs = gridspec.GridSpec(n_rows, 3) 
    plt.subplots_adjust(hspace=0.54,wspace=0.27)

    for parameter,sub in zip(parameters,subs):
        plt.subplot(sub)
        for condition in conditions:
            data = df[df.Condition == condition][parameter]
            print data.head()
            sns.distplot(data, hist=False, kde_kws={"shade": True})

#             label('Dose ({})'.format(data.Unit.values[0]), col,title,fontsize = 15)

#             plt.legend(df['Base'].unique(), loc = 0)

# %%
plot_kdes(cell_data, ['U2OS control'], ['# Coloc Spots'])
# Out:
#   Well Name     Condition  Base  Dose Unit     Drug  # of FITC spots  \
# 0       A01  U2OS control  U2OS     0       control               48
# 1       A01  U2OS control  U2OS     0       control               64
# 2       A01  U2OS control  U2OS     0       control              107
# 3       A01  U2OS control  U2OS     0       control               31
# 4       A01  U2OS control  U2OS     0       control               36
#
#    Area_FITC  NucArea_Avg  NucIntegrated Intensity_Average  \
# 0   0.279027   279.731445                         14681150
# 1   0.294945   271.821320                         21208878
# 2   0.296126   476.046844                         35930504
# 3   0.206960   158.921982                          9765546
# 4   0.205057   152.450043                          9115531
#
#                 ...                 TxRedinAPB_Int_Intensity_Avg  \
# 0               ...                                 13321.333008
# 1               ...                                 18355.941406
# 2               ...                                 18644.291016
# 3               ...                                 22653.500000
# 4               ...                                 24807.000000
#
#    # TxRed in APB  Area_TxRedinAPB_Total  Total_Int_Intensity_FITC  \
# 0               3               1.134836                    724953
# 1              17               7.078680                   1280635
# 2              24              10.606784                   2006939
# 3               4               2.224728                    314956
# 4               6               3.325856                    380894
#
#    Total_Int_Intensity_TxRed  FITCinAPB_Int_Intensity_Total      % APB  \
# 0                     100607                          59308   3.448276
# 1                     413566                         429914   8.695652
# 2                     583211                         631949  10.958904
# 3                     290275                          61833   4.545455
# 4                     455526                          74126   6.557377
#
#    % All Coloc Spots  FITC-TxRed_Area_Total  \
# 0           5.172414              15.752872
# 1          19.565217              26.011339
# 2          18.493151              40.966457
# 3           9.090909              12.213532
# 4           9.836066              16.078716
#
#    % Coloc Spot Area/PML-TRF2 fused area
# 0                               3.851641
# 1                               9.460044
# 2                              12.150301
# 3                               6.347746
# 4                               5.171209
#
# [5 rows x 36 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-244-cd73ae035544> in <module>()
# ----> 1 plot_kdes(cell_data, ['U2OS control'], ['# Coloc Spots'])
#
# <ipython-input-243-abd32fab78ce> in plot_kdes(df, conditions, parameters, filter_frequency)
#      12             data = df[df.Condition == condition]
#      13             print data.head()
# ---> 14             sns.distplot(data, hist=False, kde_kws={"shade": True})
#      15
#      16 #             label('Dose ({})'.format(data.Unit.values[0]), col,title,fontsize = 15)
#
# /home/carlos/anaconda/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     551             line, = ax.plot(0, a.mean())
#     552         else:
# --> 553             line, = ax.plot(a.mean(), 0)
#     554         color = line.get_color()
#     555         line.remove()
#
# /home/carlos/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      64         dtype = mu.dtype('f8')
#      65
# ---> 66     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      67     if isinstance(ret, mu.ndarray):
#      68         ret = um.true_divide(
#
# TypeError: cannot concatenate 'str' and 'float' objects
