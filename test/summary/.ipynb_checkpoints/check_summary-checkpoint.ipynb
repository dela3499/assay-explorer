# %%
import pandas as pd
execfile("/home/carlos/projects/sens/data analysis/src/moldev_utils.py")

# %%
py_summary = pd.read_csv("moldev_summary.csv").rename(columns={"Unnamed: 1":"func"})
ex_summary = pd.read_csv("excel_summary.csv")\
                .rename(columns={"Unnamed: 0":"Condition", "Unnamed: 1": "func"})\
                .rename(columns=rename_col)\
                .dropna(how='all', axis=1)
ex_summary['Condition'] = ex_summary['Condition'].fillna(method='ffill');

# %%
py_summary.head()
# Out:
#              Condition   func  # Coloc Spots  # FITCinAPB spots  \
# 0  143B 0.08 uM drug A  count     864.000000         864.000000
# 1  143B 0.08 uM drug A   mean       1.650463           1.619213
# 2  143B 0.08 uM drug A    std       1.650324           1.619594
# 3  143B 0.08 uM drug A    min       0.000000           0.000000
# 4  143B 0.08 uM drug A    25%       0.000000           0.000000
#
#    # TxRed in APB   # of APBs  # of FITC spots  # of TxRed spots       % APB  \
# 0      864.000000  864.000000       864.000000        864.000000  864.000000
# 1        1.572917    0.422454        20.311343         16.416667    1.000236
# 2        1.553006    0.699946        12.799879          6.425435    1.694089
# 3        0.000000    0.000000         0.000000          3.000000    0.000000
# 4        0.000000    0.000000        10.000000         12.000000    0.000000
#
#    % All Coloc Spots        ...          Integrated Intensity_FITC  \
# 0         864.000000        ...                         847.000000
# 1           4.024086        ...                        5627.627811
# 2           3.621000        ...                        5854.833594
# 3           0.000000        ...                        1823.500000
# 4           0.000000        ...                        4651.430420
#
#    Integrated Intensity_TxRed  NucArea_Avg  NucIntegrated Intensity_Average  \
# 0                  864.000000   864.000000                       864.000000
# 1                16088.489605   275.693155                  15125812.234954
# 2                 5050.459264    78.749873                   4474341.087315
# 3                 3854.166748   102.112770                   5742542.000000
# 4                12554.692627   215.551426                  11413960.000000
#
#    Total_Area_Coloc  Total_Area_FITC  Total_Area_TxRed  \
# 0        605.000000       847.000000        864.000000
# 1          0.199461         3.754840          7.523009
# 2          0.163950         2.505783          2.751390
# 3          0.011200         0.078652          1.033712
# 4          0.067400         1.629220          5.716315
#
#    Total_Int_Intensity_FITC  Total_Int_Intensity_TxRed  \
# 0                847.000000                 864.000000
# 1             120318.096812              259600.996528
# 2              91380.534272              120018.328277
# 3               2046.000000               23125.000000
# 4              49132.500000              181593.250000
#
#    TxRedinAPB_Int_Intensity_Avg
# 0                    605.000000
# 1                  20784.751151
# 2                  10651.260701
# 3                   2177.000000
# 4                  14023.000000
#
# [5 rows x 32 columns]

# %%
ex_summary.head()
# Out:
#          Condition        func  # of FITC spots    Area_FITC  NucArea_Avg  \
# 0     U2OS control         Avg        46.130687     0.279455   247.966569
# 1     U2OS control         Std        18.285705     0.040584    89.377675
# 2     U2OS control         SEM         0.525894     0.001167     2.570490
# 3     U2OS control  Cell Count      1209.000000  1209.000000  1209.000000
# 4  U2OS 0.22% DMSO         Avg        44.850248     0.276349   238.564922
#
#    NucIntegrated Intensity_Average  Integrated Intensity_FITC   Area_TxRed  \
# 0                  14987504.851117               16090.781114     0.391179
# 1                   6286629.723263                4857.437634     0.084088
# 2                    180802.624831                 139.699253     0.002418
# 3                      1209.000000                1209.000000  1209.000000
# 4                  12948069.627395               13811.139671     0.352653
#
#    Integrated Intensity_TxRed  # of TxRed spots        ...         \
# 0                16872.618499         16.320926        ...
# 1                 6859.505829         14.387882        ...
# 2                  197.278465          0.413794        ...
# 3                 1209.000000       1209.000000        ...
# 4                12767.998875         17.784954        ...
#
#    TxRedinAPB_Int_Intensity_Avg  # TxRed in APB  Area_TxRedinAPB_Total  \
# 0                  20722.859978        7.799007               3.644488
# 1                   9769.521857        5.059919               2.507688
# 2                    282.257116        0.145523               0.072451
# 3                   1198.000000     1209.000000            1198.000000
# 4                  16491.487022        7.410220               3.283836
#
#    Total_Int_Intensity_FITC  Total_Int_Intensity_TxRed  \
# 0             763779.882548              298983.925558
# 1             430355.119875              834875.734921
# 2              12376.955333               24010.913785
# 3               1209.000000                1209.000000
# 4             635603.036906              227660.003549
#
#    FITCinAPB_Int_Intensity_Total        % APB  % All Coloc Spots  \
# 0                  196354.621035     7.052451          13.249021
# 1                  154376.770187     4.293888           5.594201
# 2                    4460.191868     0.123492           0.160888
# 3                    1198.000000  1209.000000        1209.000000
# 4                  162075.676703     5.517451          12.689154
#
#    FITC-TxRed_Area_Total  % Coloc Spot Area/PML-TRF2 fused area
# 0              17.965825                               7.017365
# 1               8.964187                               4.004865
# 2               0.257809                               0.115179
# 3            1209.000000                            1209.000000
# 4              17.565728                               5.668392
#
# [5 rows x 32 columns]
