# %%
from pandas import DataFrame as df
import pandas as pd
import numpy as np
from toolz import thread_first
# from utils import curry_funcs,\
#                   drop_matching_columns,\
#                   add_normalized_columns,\
#                   headers_to_column,\
#                   summarize_groups
                
execfile('../src/utils.py')

curry_funcs(['pd.read_csv',
             'df.dropna',
             'df.rename'])

###################################################
### Cell Data Config ##############################
###################################################

# String -> String
def rename_column(col):
    """ Rename column col to remove whitespace, backslashes, prefixes, 
        and suffixes (esp. large parenthetic suffix). """
    if col.startswith('Cell:'):
        return col.split('(')[0].lstrip("Cell:").rstrip('/').strip(' ')
    else: 
        return col.split('(')[0].rstrip('/').strip(' ')

def check_cell_data(dataframe):
    return dataframe

# type CellConfig = {
#        path      :: String,
#        skiprows  :: Int | [Int],
#        dropcols  :: [RegexString],
#        normcols  :: [[String,[String],[String]]],
#        colrename :: (String -> String),
#        check     :: (DataFrame -> DataFrame | Exception) }

cell_config = dict(
    path = '../input/moldev_data.csv',
    skiprows = 4,
    dropcols = ['Cell ID',
                'Site ID',
                'MEASUREMENT SET ID',
                '.*ObjectID.*',
                '\.[0-9]*\Z'],
    normcols = [['Normalized APB spots',  
                  ['# of APBs'],
                  ['# of FITC spots', '# of TxRed spots']],
                ['Normalized Coloc area', 
                  ['Area_Coloc_Avg'],
                  ['Area_FITC','Area_TxRed']],
                ['Normalized Coloc spots',
                  ['# Coloc Spots'],   
                  ['# of FITC spots', '# of TxRed spots']]],
    colrename = rename_column,
    check = check_cell_data
    )

###################################################
### Lookup Config #################################
###################################################

def check_lookup_data(dataframe):
    return dataframe

# type LookupConfig = {
#        path      :: String,
#        skiprows  :: Int | [Int],
#        check     :: (DataFrame -> DataFrame | Exception) }

lookup_config = dict(
    path = '../input/conditions_and_wells.csv',
    skiprows = [1],
    check = check_lookup_data
    )

###################################################
### Analysis ######################################
###################################################

# CellConfig -> DataFrame
def get_cell_data(c):
    return thread_first(c['path'],
                        pd.read_csv(skiprows=c['skiprows']),
                        df.dropna(axis=1,how='all'),
                        (drop_matching_columns,c['dropcols']),
                        df.rename(columns=c['colrename']),
                        (add_normalized_columns,c['normcols']),
                        c['check'])

# LookupConfig -> DataFrame
def get_lookup_data(c):
    return thread_first(c['path'],
                        pd.read_csv(skiprows=c['skiprows']),
                        df.dropna(axis=1,how='all'),
                        headers_to_column,
                        df.rename(columns=dict(
                                    values = 'Well Name',
                                    label = 'Condition')),
                        c['check'])

def summarize_conditions(data,c):
    return thread_first(data,
                        (df.groupby,c['groupby']),
                        (summarize_groups,c['funcs'],c['fnames']))

data = pd.merge(get_cell_data(cell_config),
                get_lookup_data(lookup_config),
                on = 'Well Name')



funcs = [df.mean,df.std,df.sem,df.count,df.min,df.max]
fnames = ['avg','std','sem','count','min','max']

condition_config = dict(groupby = 'Condition', funcs = funcs, fnames = fnames)
well_config = dict(groupby = 'Well Name', funcs = funcs, fnames = fnames)

condition_data = summarize_conditions(data.drop('Well Name',axis=1),
                                      condition_config)

well_data = summarize_conditions(data,well_config)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-87-5dfbb14bb8ea> in <module>()
#     121
#     122 condition_data = summarize_conditions(data.drop('Well Name',axis=1),
# --> 123                                       condition_config)
#     124
#     125 well_data = summarize_conditions(data,well_config)
#
# <ipython-input-87-5dfbb14bb8ea> in summarize_conditions(data, c)
#     106     return thread_first(data,
#     107                         (df.groupby,c['groupby']),
# --> 108                         (summarize_groups,c['funcs'],c['fnames']))
#     109
#     110 data = pd.merge(get_cell_data(cell_config),
#
# /home/carlos/anaconda/lib/python2.7/site-packages/toolz/functoolz.pyc in thread_first(val, *forms)
#      44             args = (val,) + args
#      45             return func(*args)
# ---> 46     return reduce(evalform_front, forms, val)
#      47
#      48
#
# /home/carlos/anaconda/lib/python2.7/site-packages/toolz/functoolz.pyc in evalform_front(val, form)
#      43             func, args = form[0], form[1:]
#      44             args = (val,) + args
# ---> 45             return func(*args)
#      46     return reduce(evalform_front, forms, val)
#      47
#
# /home/carlos/projects/sens/data analysis/src/utils.py in summarize_groups(groups, funcs, names)
#     101                                       names = names)),
#     102                        pd.concat,
# --> 103                        reset_index)
#
# /home/carlos/anaconda/lib/python2.7/site-packages/toolz/functoolz.pyc in thread_last(val, *forms)
#      83             args = args + (val,)
#      84             return func(*args)
# ---> 85     return reduce(evalform_back, forms, val)
#      86
#      87
#
# /home/carlos/anaconda/lib/python2.7/site-packages/toolz/functoolz.pyc in evalform_back(val, form)
#      82             func, args = form[0], form[1:]
#      83             args = args + (val,)
# ---> 84             return func(*args)
#      85     return reduce(evalform_back, forms, val)
#      86
#
# /home/carlos/anaconda/lib/python2.7/site-packages/toolz/functoolz.pyc in __call__(self, *args, **kwargs)
#     209     def __call__(self, *args, **kwargs):
#     210         try:
# --> 211             return self._partial(*args, **kwargs)
#     212         except TypeError:
#     213             # If there was a genuine TypeError
#
# /home/carlos/projects/sens/data analysis/src/utils.py in summarize(dataframe, funcs, names)
#      84       vals = list(set(dataframe[col].values))
#      85       assert len(vals) == 2, \
# ---> 86         "Values in '{}' column should be the same in a group. Found multiple values: {}".format(col,vals)
#      87       summary[col] = dataframe[col].iloc[0]
#      88
#
# AssertionError: Values in 'Condition' column should be the same in a group. Found multiple values: ['143B 0.08 uM drug A']

# %%
well_data[['Condition','Function','Well Name']]
# Out:
#                   Condition Function Well Name
# 0              U2OS control      avg       A01
# 1              U2OS control      std       A01
# 2              U2OS control      sem       A01
# 3              U2OS control    count       A01
# 4              U2OS control      min       A01
# 5              U2OS control      max       A01
# 6           U2OS 0.22% DMSO      avg       A02
# 7           U2OS 0.22% DMSO      std       A02
# 8           U2OS 0.22% DMSO      sem       A02
# 9           U2OS 0.22% DMSO    count       A02
# 10          U2OS 0.22% DMSO      min       A02
# 11          U2OS 0.22% DMSO      max       A02
# 12      U2OS 11.1 uM drug A      avg       A03
# 13      U2OS 11.1 uM drug A      std       A03
# 14      U2OS 11.1 uM drug A      sem       A03
# 15      U2OS 11.1 uM drug A    count       A03
# 16      U2OS 11.1 uM drug A      min       A03
# 17      U2OS 11.1 uM drug A      max       A03
# 18      U2OS 5.55 uM drug A      avg       A04
# 19      U2OS 5.55 uM drug A      std       A04
# 20      U2OS 5.55 uM drug A      sem       A04
# 21      U2OS 5.55 uM drug A    count       A04
# 22      U2OS 5.55 uM drug A      min       A04
# 23      U2OS 5.55 uM drug A      max       A04
# 24      U2OS 2.75 uM drug A      avg       A05
# 25      U2OS 2.75 uM drug A      std       A05
# 26      U2OS 2.75 uM drug A      sem       A05
# 27      U2OS 2.75 uM drug A    count       A05
# 28      U2OS 2.75 uM drug A      min       A05
# 29      U2OS 2.75 uM drug A      max       A05
# ..                      ...      ...       ...
# 546     143B 0.34 uM drug A      avg       H08
# 547     143B 0.34 uM drug A      std       H08
# 548     143B 0.34 uM drug A      sem       H08
# 549     143B 0.34 uM drug A    count       H08
# 550     143B 0.34 uM drug A      min       H08
# 551     143B 0.34 uM drug A      max       H08
# 552     143B 0.17 uM drug A      avg       H09
# 553     143B 0.17 uM drug A      std       H09
# 554     143B 0.17 uM drug A      sem       H09
# 555     143B 0.17 uM drug A    count       H09
# 556     143B 0.17 uM drug A      min       H09
# 557     143B 0.17 uM drug A      max       H09
# 558     143B 0.08 uM drug A      avg       H10
# 559     143B 0.08 uM drug A      std       H10
# 560     143B 0.08 uM drug A      sem       H10
# 561     143B 0.08 uM drug A    count       H10
# 562     143B 0.08 uM drug A      min       H10
# 563     143B 0.08 uM drug A      max       H10
# 564            143B 1 mM HU      avg       H11
# 565            143B 1 mM HU      std       H11
# 566            143B 1 mM HU      sem       H11
# 567            143B 1 mM HU    count       H11
# 568            143B 1 mM HU      min       H11
# 569            143B 1 mM HU      max       H11
# 570  143B 5 uM Telomestatin      avg       H12
# 571  143B 5 uM Telomestatin      std       H12
# 572  143B 5 uM Telomestatin      sem       H12
# 573  143B 5 uM Telomestatin    count       H12
# 574  143B 5 uM Telomestatin      min       H12
# 575  143B 5 uM Telomestatin      max       H12
#
# [576 rows x 3 columns]
